# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly_express as ps

# %%
data = pd.read_csv('UPI apps transaction data in 2021.csv')
data.head()
# Out:
#                    UPI Banks  Volume (Mn) By Costumers  \
# 0  Airtel Payments Bank Apps                      9.04
# 1  Airtel Payments Bank Apps                      8.41
# 2  Airtel Payments Bank Apps                      7.60
# 3  Airtel Payments Bank Apps                      6.91
# 4  Airtel Payments Bank Apps                      6.14
#
#    Value (Cr) by Costumers  Volume (Mn)  Value (Cr)  Month  Year
# 0                  2248.49        15.12     5732.09     12  2021
# 1                  1923.95        15.90     5554.63     11  2021
# 2                  1491.34        14.31     4746.79     10  2021
# 3                  1520.92        11.52     3759.12      9  2021
# 4                  1396.65         9.31     2941.88      8  2021

# %%
data.shape
# Out:
# (654, 7)

# %%
data.describe()
# Out:
#        Volume (Mn) By Costumers  Value (Cr) by Costumers  Volume (Mn)  \
# count                654.000000               654.000000   654.000000
# mean                  57.960948             10943.292813    60.460321
# std                  256.842682             49450.615924   258.686922
# min                    0.010000                 0.410000     0.010000
# 25%                    0.050000                21.132500     0.050000
# 50%                    0.250000                60.640000     0.250000
# 75%                    2.357500               401.312500     2.357500
# max                 2077.600000            394565.580000  2077.600000
#
#           Value (Cr)       Month    Year
# count     654.000000  654.000000   654.0
# mean    11134.196682    6.571865  2021.0
# std     49588.538504    3.488797     0.0
# min         0.410000    1.000000  2021.0
# 25%        21.132500    3.250000  2021.0
# 50%        60.745000    7.000000  2021.0
# 75%       407.062500   10.000000  2021.0
# max    394565.580000   12.000000  2021.0

# %%
data['UPI Banks'].value_counts().head(50)
# Out:
# Federal Bank App                12
# Standard Chartered Bank App     12
# Axis Bank Apps                  12
# Dena Bank App                   12
# State Bank of India Apps        12
# Jio Payments Bank App           12
# Karnataka Bank App              12
# Kotak Mahindra Bank Apps        12
# UCO Bank App                    12
# DBS Digibank App                12
# Paytm Payments Bank App         12
# Samsung Pay                     12
# HDFC Bank Apps                  12
# Bajaj Finserv                   12
# Yes Bank Apps                   12
# Fino Payments bank App          12
# IDBI Bank App                   12
# Bank of Baroda Apps             12
# HSBC Bank App                   12
# Citi Bank App                   12
# Canara Bank App                 12
# Punjab National Bank App        12
# MI Pay                          12
# South Indian Bank App           12
# Deutsche Bank App               12
# Cointab                         12
# AU Small Finance Bank App       12
# Union Bank Apps                 12
# Karur Vysya Bank App            12
# Cred                            12
# ICICI Bank Apps                 12
# BHIM                            12
# Airtel Payments Bank Apps       12
# IndusInd Bank App               12
# PhonePe                         12
# Mobikwik                        12
# Ultracash                       12
# IDFC Bank App                   12
# MakeMy Trip                     12
# India Post Payments Bank App    12
# Google Pay                      12
# Bank of Maharashtra App         12
# Central Bank of India App       12
# Amazon Pay                      12
# Indian Bank App                 12
# RBL Bank App                    12
# Allahabad Bank App              11
# WhatsApp                        11
# YuvaPay                         11
# Bank of India App                9
# Name: UPI Banks, dtype: int64

# %%
plt.figure(figsize=(20,5))
sns.countplot(x='UPI Banks',data=data)
plt.title("No of UPI transactions types")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='UPI Banks',y='Month',data=data)
plt.title("No of UPI transactions types")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.set_style("whitegrid")
sns.lineplot(x='Month',y='Volume (Mn) By Costumers',data=data)
plt.xlabel('Month',fontweight='bold',size = 12) 
plt.ylabel('Volume (Mn) By Costumers',fontweight='bold',size = 12) 
plt.title("Trend Month v/s Volume (Mn) By Costumers ",fontweight='bold',size = 12)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x="Month",y='Value (Cr) by Costumers',data=data)
plt.xlabel('Month',fontweight='bold',size = 12) 
plt.ylabel('Value (Cr) by Costumers',fontweight='bold',size = 12) 
plt.title(" Trend Month v/s Value (Cr) by Costumers ",fontweight='bold',size = 12)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x="Month",y='Volume (Mn)',data=data)
plt.xlabel('Month',fontweight='bold',size = 12) 
plt.ylabel('Volume (Mn)',fontweight='bold',size = 12) 
plt.title(" Trend Month v/s Volume (Mn) ",fontweight='bold',size = 12)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x="Month",y='Value (Cr)',data=data)
plt.xlabel('Month',fontweight='bold',size = 12) 
plt.ylabel('Value (Cr)',fontweight='bold',size = 12) 
plt.title(" Trend Month v/s Value (Cr)",fontweight='bold',size = 12)
plt.show()

# %%
total = data.groupby(['UPI Banks']).agg({'Volume (Mn) By Costumers':'sum'}).reset_index()

# %%
top_10_highest_volume_mn = total.sort_values(by = 'Volume (Mn) By Costumers',ascending = False)

# %%
top_10_highest_volume_mn.head(10)
# Out:
#                     UPI Banks  Volume (Mn) By Costumers
# 51                    PhonePe                  17470.81
# 26                 Google Pay                  13541.88
# 50    Paytm Payments Bank App                   4827.38
# 3                  Amazon Pay                    704.15
# 67              Yes Bank Apps                    292.50
# 6                        BHIM                    289.43
# 29            ICICI Bank Apps                    191.06
# 5              Axis Bank Apps                     99.57
# 16                       Cred                     80.96
# 1   Airtel Payments Bank Apps                     67.37

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='UPI Banks',y='Volume (Mn) By Costumers',data=top_10_highest_volume_mn.head(10))
plt.title("Top 10 highest volume")
plt.xticks(rotation=90)
plt.show()

# %%
total = data.groupby(['UPI Banks']).agg({'Value (Cr) by Costumers':'sum'}).reset_index()
top_10_highest_volume_cr = total.sort_values(by = 'Value (Cr) by Costumers',ascending = False)

# %%
top_10_highest_volume_cr.head(10)
# Out:
#                     UPI Banks  Value (Cr) by Costumers
# 51                    PhonePe               3365727.16
# 26                 Google Pay               2737496.81
# 50    Paytm Payments Bank App                573899.84
# 16                       Cred                 97013.60
# 6                        BHIM                 91106.89
# 67              Yes Bank Apps                 61298.95
# 3                  Amazon Pay                 60962.34
# 29            ICICI Bank Apps                 60568.91
# 60   State Bank of India Apps                 25357.37
# 1   Airtel Payments Bank Apps                 13317.81

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='UPI Banks',y='Value (Cr) by Costumers',data=top_10_highest_volume_cr.head(10))
plt.title("Top 10 highest volume cr")
plt.xticks(rotation=90)
plt.show()

# %%
total = data.groupby(['UPI Banks']).agg({'Volume (Mn)':'sum'}).reset_index()
top_10_highest_volume_Mn = total.sort_values(by = 'Volume (Mn)',ascending = False)

# %%
top_10_highest_volume_Mn.head(10)
# Out:
#                     UPI Banks  Volume (Mn)
# 51                    PhonePe     17470.81
# 26                 Google Pay     13541.88
# 50    Paytm Payments Bank App      5640.23
# 5              Axis Bank Apps       841.62
# 3                  Amazon Pay       704.15
# 67              Yes Bank Apps       293.08
# 6                        BHIM       289.43
# 29            ICICI Bank Apps       227.74
# 1   Airtel Payments Bank Apps       109.80
# 16                       Cred        80.96

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='UPI Banks',y='Volume (Mn)',data=top_10_highest_volume_Mn.head(10))
plt.title("Top 10 highest volume Mn")
plt.xticks(rotation=90)
plt.show()

# %%
total = data.groupby(['UPI Banks']).agg({'Value (Cr)':'sum'}).reset_index()
top_10_highest_volume_Cr = total.sort_values(by = 'Value (Cr)',ascending = False)

# %%
top_10_highest_volume_Cr.head(10)
# Out:
#                     UPI Banks  Value (Cr)
# 51                    PhonePe  3365727.06
# 26                 Google Pay  2737496.81
# 50    Paytm Payments Bank App   669189.79
# 16                       Cred    97013.60
# 6                        BHIM    91106.89
# 29            ICICI Bank Apps    62297.95
# 67              Yes Bank Apps    61299.32
# 3                  Amazon Pay    60962.34
# 1   Airtel Payments Bank Apps    40586.97
# 60   State Bank of India Apps    25357.39

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='UPI Banks',y='Value (Cr)',data=top_10_highest_volume_Cr.head(10))
plt.title("Top 10 highest volume Cr")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # PhonePe users

# %%
phonePe_Payment = (data.loc[data['UPI Banks'] == 'PhonePe'])

# %%
phonePe_Payment
# Out:
#     UPI Banks  Volume (Mn) By Costumers  Value (Cr) by Costumers  Volume (Mn)  \
# 487   PhonePe                   2077.60                394565.58      2077.60
# 488   PhonePe                   1911.21                365044.32      1911.21
# 489   PhonePe                   1937.57                365845.39      1937.57
# 490   PhonePe                   1653.19                306437.37      1653.19
# 491   PhonePe                   1622.95                301644.80      1622.95
# 492   PhonePe                   1492.09                288573.00      1492.09
# 493   PhonePe                   1292.71                262565.88      1292.71
# 494   PhonePe                   1149.84                234123.57      1149.84
# 495   PhonePe                   1189.89                234023.33      1189.89
# 496   PhonePe                   1199.51                231412.33      1199.51
# 497   PhonePe                    975.53                189517.82       975.53
# 498   PhonePe                    968.72                191973.77       968.72
#
#      Value (Cr)  Month  Year
# 487   394565.58     12  2021
# 488   365044.32     11  2021
# 489   365845.39     10  2021
# 490   306437.37      9  2021
# 491   301644.80      8  2021
# 492   288572.90      7  2021
# 493   262565.88      6  2021
# 494   234123.57      5  2021
# 495   234023.33      4  2021
# 496   231412.33      3  2021
# 497   189517.82      2  2021
# 498   191973.77      1  2021

# %%
plt.figure(figsize=(10,6))
sns.set_style("whitegrid")
sns.lineplot(x='Month',y='Volume (Mn) By Costumers',data =phonePe_Payment)
plt.xlabel('Month',fontweight='bold',size = 12) 
plt.ylabel('Volume (Mn) By Costumers',fontweight='bold',size = 12) 
plt.title("Trend Month v/s Volume (Mn) By Costumers for only phonePe_Payment ",fontweight='bold',size = 12)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.set_style("whitegrid")
sns.lineplot(x='Month',y='Value (Cr) by Costumers',data =phonePe_Payment)
plt.xlabel('Month',fontweight='bold',size = 12) 
plt.ylabel('Value (Cr) by Costumers',fontweight='bold',size = 12) 
plt.title("Trend Month v/s Value (Cr) by Costumers phonePe_Payment",fontweight='bold',size = 12)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.set_style("whitegrid")
sns.lineplot(x='Month',y='Volume (Mn)',data =phonePe_Payment)
plt.xlabel('Month',fontweight='bold',size = 12) 
plt.ylabel('Volume (Mn)',fontweight='bold',size = 12) 
plt.title("Trend Month v/s Volume (Mn) by Costumers phonePe_Payment",fontweight='bold',size = 12)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.set_style("whitegrid")
sns.lineplot(x='Month',y='Value (Cr)',data =phonePe_Payment)
plt.xlabel('Month',fontweight='bold',size = 12) 
plt.ylabel('Value (Cr)',fontweight='bold',size = 12) 
plt.title("Trend Month v/s Value (Cr) phonePe_Payment",fontweight='bold',size = 12)
plt.show()

# %% [markdown]
# # Gpay Users

# %%
GPay = (data.loc[data['UPI Banks'] == 'Google Pay'])

# %%
GPay
# Out:
#       UPI Banks  Volume (Mn) By Costumers  Value (Cr) by Costumers  \
# 252  Google Pay                   1587.43                302989.79
# 253  Google Pay                   1447.84                283357.99
# 254  Google Pay                   1451.93                287491.46
# 255  Google Pay                   1294.56                250393.65
# 256  Google Pay                   1243.75                244453.05
# 257  Google Pay                   1119.16                230847.54
# 258  Google Pay                    972.26                207287.73
# 259  Google Pay                    880.59                187136.95
# 260  Google Pay                    905.96                190106.71
# 261  Google Pay                    957.01                201185.14
# 262  Google Pay                    827.86                174455.33
# 263  Google Pay                    853.53                177791.47
#
#      Volume (Mn)  Value (Cr)  Month  Year
# 252      1587.43   302989.79     12  2021
# 253      1447.84   283357.99     11  2021
# 254      1451.93   287491.46     10  2021
# 255      1294.56   250393.65      9  2021
# 256      1243.75   244453.05      8  2021
# 257      1119.16   230847.54      7  2021
# 258       972.26   207287.73      6  2021
# 259       880.59   187136.95      5  2021
# 260       905.96   190106.71      4  2021
# 261       957.01   201185.14      3  2021
# 262       827.86   174455.33      2  2021
# 263       853.53   177791.47      1  2021

# %%
plt.figure(figsize=(10,6))
sns.set_style("whitegrid")
sns.lineplot(x='Month',y='Volume (Mn) By Costumers',data =GPay)
plt.xlabel('Month',fontweight='bold',size = 12) 
plt.ylabel('Volume (Mn) By Costumers',fontweight='bold',size = 12) 
plt.title("Trend Month v/s Volume (Mn) By Costumers for only GPay ",fontweight='bold',size = 12)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.set_style("whitegrid")
sns.lineplot(x='Month',y='Value (Cr) by Costumers',data = GPay)
plt.xlabel('Month',fontweight='bold',size = 12) 
plt.ylabel('Value (Cr) by Costumers',fontweight='bold',size = 12) 
plt.title("Trend Month v/s Value (Cr) by Costumers GPay",fontweight='bold',size = 12)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.set_style("whitegrid")
sns.lineplot(x='Month',y='Volume (Mn)',data =GPay)
plt.xlabel('Month',fontweight='bold',size = 12) 
plt.ylabel('Volume (Mn)',fontweight='bold',size = 12) 
plt.title("Trend Month v/s Volume (Mn) by Costumers GPay",fontweight='bold',size = 12)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.set_style("whitegrid")
sns.lineplot(x='Month',y='Value (Cr)',data =GPay)
plt.xlabel('Month',fontweight='bold',size = 12) 
plt.ylabel('Value (Cr)',fontweight='bold',size = 12) 
plt.title("Trend Month v/s Value (Cr) GPay",fontweight='bold',size = 12)
plt.show()

# %% [markdown]
# # Paytm Users

# %%
Paytm = (data.loc[data['UPI Banks'] == 'Paytm Payments Bank App'])

# %%
Paytm.head(10)
# Out:
#                    UPI Banks  Volume (Mn) By Costumers  \
# 475  Paytm Payments Bank App                    612.71
# 476  Paytm Payments Bank App                    543.71
# 477  Paytm Payments Bank App                    542.57
# 478  Paytm Payments Bank App                    462.71
# 479  Paytm Payments Bank App                    423.63
# 480  Paytm Payments Bank App                    387.85
# 481  Paytm Payments Bank App                    326.53
# 482  Paytm Payments Bank App                    290.69
# 483  Paytm Payments Bank App                    320.78
# 484  Paytm Payments Bank App                    344.99
#
#      Value (Cr) by Costumers  Volume (Mn)  Value (Cr)  Month  Year
# 475                 71874.13       706.37    88094.49     12  2021
# 476                 66920.55       631.30    81403.37     11  2021
# 477                 64727.41       632.18    80508.04     10  2021
# 478                 53793.06       543.55    61417.53      9  2021
# 479                 50021.40       498.65    56319.62      8  2021
# 480                 46406.52       454.06    51694.41      7  2021
# 481                 40614.09       383.05    44981.11      6  2021
# 482                 35715.48       343.81    43741.16      5  2021
# 483                 36859.20       372.70    41469.53      4  2021
# 484                 38653.06       401.16    43221.25      3  2021

# %%
plt.figure(figsize=(10,6))
sns.set_style("whitegrid")
sns.lineplot(x='Month',y='Volume (Mn) By Costumers',data = Paytm)
plt.xlabel('Month',fontweight='bold',size = 12) 
plt.ylabel('Volume (Mn) By Costumers',fontweight='bold',size = 12) 
plt.title("Trend Month v/s Volume (Mn) By Costumers for only Paytm",fontweight='bold',size = 12)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.set_style("whitegrid")
sns.lineplot(x='Month',y='Value (Cr) by Costumers',data = Paytm)
plt.xlabel('Month',fontweight='bold',size = 12) 
plt.ylabel('Value (Cr) by Costumers',fontweight='bold',size = 12) 
plt.title("Trend Month v/s Value (Cr) by Costumers Paytm",fontweight='bold',size = 12)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.set_style("whitegrid")
sns.lineplot(x='Month',y='Volume (Mn)',data =Paytm)
plt.xlabel('Month',fontweight='bold',size = 12) 
plt.ylabel('Volume (Mn)',fontweight='bold',size = 12) 
plt.title("Trend Month v/s Volume (Mn) by Costumers Paytm",fontweight='bold',size = 12)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.set_style("whitegrid")
sns.lineplot(x='Month',y='Value (Cr)',data =Paytm)
plt.xlabel('Month',fontweight='bold',size = 12) 
plt.ylabel('Value (Cr)',fontweight='bold',size = 12) 
plt.title("Trend Month v/s Value (Cr) Paytm",fontweight='bold',size = 12)
plt.show()
